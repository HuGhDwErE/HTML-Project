# %%
import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# 1. Create a tiny sample dataset of Skyrim items
data = {
    "item_name": [
        "Daedric Boots of Fire Suppression",
        "Ebony Armor of Peerless Destruction",
        "Ring of Eminent Fortify Magicka",
        "Iron Sword of Burning",
        "Glass Shield of Grounding"
    ],
    "description": [
        "Increases Fire Resistance by 50%. Heavy armor boots.",
        "Destruction spells cost 25% less magicka to cast. Heavy torso armor.",
        "Increases total Magicka capacity by 40 points.",
        "Burns the target for 10 points of fire damage.",
        "Increases Shock Resistance by 40%. Light shield."
    ]
}
df = pd.DataFrame(data)

# 2. Load a lightweight, free embedding model (runs locally on your CPU)
# This model converts text into a 384-dimensional vector space.
model = SentenceTransformer('all-MiniLM-L6-v2')

# 3. Generate vectors for your items by combining their name and description
df['combined_text'] = df['item_name'] + " - " + df['description']
item_embeddings = model.encode(df['combined_text'].tolist())

# 4. Define your search query
user_query = "something to protect me from fire dragons"
query_embedding = model.encode([user_query])

# 5. Run the Exact k-NN Search using Cosine Similarity
similarities = cosine_similarity(query_embedding, item_embeddings)[0]

# 6. Add results to dataframe and sort by highest similarity
df['similarity_score'] = similarities
results = df.sort_values(by='similarity_score', ascending=False)

# Display the top matches
print(f"Results for query: '{user_query}'\n")
print(results[['item_name', 'similarity_score']].to_string(index=False))
# Out:
# '[WinError 10054] An existing connection was forcibly closed by the remote host' thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# Retrying in 1s [Retry 1/5].
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 27
#      23 df = pd.DataFrame(data)
#      24
#      25 # 2. Load a lightweight, free embedding model (runs locally on your CPU)
#      26 # This model converts text into a 384-dimensional vector space.
# ---> 27 model = SentenceTransformer('all-MiniLM-L6-v2')
#      28
#      29 # 3. Generate vectors for your items by combining their name and description
#      30 df['combined_text'] = df['item_name'] + " - " + df['description']
#
# File c:\Users\hugh.dwyer\OneDrive - NSW Department of Education\Desktop\HTML Project\skyrim-semantic-search\venv\Lib\site-packages\sentence_transformers\util\decorators.py:41, in deprecated_kwargs.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      39         else:
#      40             kwargs.pop(old_name)
# ---> 41 return func(*args, **kwargs)
#
# File c:\Users\hugh.dwyer\OneDrive - NSW Department of Education\Desktop\HTML Project\skyrim-semantic-search\venv\Lib\site-packages\sentence_transformers\sentence_transformer\model.py:184, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, cache_folder, trust_remote_code, revision, local_files_only, token, use_auth_token, model_kwargs, processor_kwargs, config_kwargs, model_card_data, backend, similarity_fn_name, truncate_dim)
#     179         raise ValueError(
#     180             "Both `token` and `use_auth_token` are specified. Please only specify the `token` argument."
#     181         )
#     182     token = use_auth_token
# --> 184 super().__init__(
#     185     model_name_or_path=model_name_or_path,
#     186     modules=modules,
#     187     device=device,
#     188     cache_folder=cache_folder,
#     189     trust_remote_code=trust_remote_code,
#     190     revision=revision,
#     191     local_files_only=local_files_only,
#     192     token=token,
#     193     model_kwargs=model_kwargs,
#     194     processor_kwargs=processor_kwargs,
#     195     config_kwargs=config_kwargs,
#     196     model_card_data=model_card_data,
#     197     backend=backend,
#     198     prompts=prompts,
#     199     default_prompt_name=default_prompt_name,
#     200 )
#     201 self.model_card_data: SentenceTransformerModelCardData
#     203 # Handle INSTRUCTOR models
#
# File c:\Users\hugh.dwyer\OneDrive - NSW Department of Education\Desktop\HTML Project\skyrim-semantic-search\venv\Lib\site-packages\sentence_transformers\base\model.py:204, in BaseModel.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, cache_folder, trust_remote_code, revision, local_files_only, token, model_kwargs, processor_kwargs, config_kwargs, model_card_data, backend)
#     201         model_name_or_path = f"{self.default_huggingface_organization}/{model_name_or_path}"
#     203 if model_name_or_path:
# --> 204     modules, self.module_kwargs = self._load_modules(
#     205         model_name_or_path,
#     206         token=token,
#     207         cache_folder=cache_folder,
#     208         revision=revision,
#     209         trust_remote_code=trust_remote_code,
#     210         local_files_only=local_files_only,
#     211         model_kwargs=model_kwargs,
#     212         processor_kwargs=processor_kwargs,
#     213         config_kwargs=config_kwargs,
#     214     )
#     216 if modules is not None and not isinstance(modules, OrderedDict):
#     217     modules = OrderedDict([(str(idx), module) for idx, module in enumerate(modules)])
#
# File c:\Users\hugh.dwyer\OneDrive - NSW Department of Education\Desktop\HTML Project\skyrim-semantic-search\venv\Lib\site-packages\sentence_transformers\base\model.py:972, in BaseModel._load_modules(self, model_name_or_path, token, cache_folder, revision, trust_remote_code, local_files_only, model_kwargs, processor_kwargs, config_kwargs)
#     960 load_kwargs = {
#     961     "token": token,
#     962     "cache_folder": cache_folder,
#    (...)    968     "config_kwargs": config_kwargs,
#     969 }
#     971 # Check if this is a Sentence Transformer model
# --> 972 modules_json_path = load_file_path(
#     973     model_name_or_path,
#     974     "modules.json",
#     975     token=token,
#     976     cache_folder=cache_folder,
#     977     revision=revision,
#     978     local_files_only=local_files_only,
#     979 )
#     980 if modules_json_path is None:
#     981     logger.info(f"No modules.json found for {model_name_or_path}, initializing a new {self.model_type} model.")
#
# File c:\Users\hugh.dwyer\OneDrive - NSW Department of Education\Desktop\HTML Project\skyrim-semantic-search\venv\Lib\site-packages\sentence_transformers\util\file_io.py:116, in load_file_path(model_name_or_path, filename, subfolder, token, cache_folder, revision, local_files_only)
#     114 file_path = Path(subfolder, filename)
#     115 try:
# --> 116     return hf_hub_download(
#     117         model_name_or_path,
#     118         filename=file_path.name,
#     119         subfolder=file_path.parent.as_posix(),
#     120         revision=revision,
#     121         library_name="sentence-transformers",
#     122         token=token,
#     123         cache_dir=cache_folder,
#     124         local_files_only=local_files_only,
#     125     )
#     126 except (EntryNotFoundError, HFValidationError, LocalEntryNotFoundError) as exc:
#     127     # Unambiguous "not found" cases. Other errors (auth, rate limit, network)
#     128     # propagate so callers don't silently fall back to a different model.
#     129     logger.debug(f"Could not load {filename!r} from {model_name_or_path!r}: {exc}")
#
# File c:\Users\hugh.dwyer\OneDrive - NSW Department of Education\Desktop\HTML Project\skyrim-semantic-search\venv\Lib\site-packages\huggingface_hub\utils\_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File c:\Users\hugh.dwyer\OneDrive - NSW Department of Education\Desktop\HTML Project\skyrim-semantic-search\venv\Lib\site-packages\huggingface_hub\file_download.py:1015, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, etag_timeout, token, local_files_only, headers, endpoint, tqdm_class, dry_run)
#     994     return _hf_hub_download_to_local_dir(
#     995         # Destination
#     996         local_dir=local_dir,
#    (...)   1012         dry_run=dry_run,
#    1013     )
#    1014 else:
# -> 1015     return _hf_hub_download_to_cache_dir(
#    1016         # Destination
#    1017         cache_dir=cache_dir,
#    1018         # File info
#    1019         repo_id=repo_id,
#    1020         filename=filename,
#    1021         repo_type=repo_type,
#    1022         revision=revision,
#    1023         # HTTP info
#    1024         endpoint=endpoint,
#    1025         etag_timeout=etag_timeout,
#    1026         headers=hf_headers,
#    1027         token=token,
#    1028         # Additional options
#    1029         local_files_only=local_files_only,
#    1030         force_download=force_download,
#    1031         tqdm_class=tqdm_class,
#    1032         dry_run=dry_run,
#    1033     )
#
# File c:\Users\hugh.dwyer\OneDrive - NSW Department of Education\Desktop\HTML Project\skyrim-semantic-search\venv\Lib\site-packages\huggingface_hub\file_download.py:1148, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, force_download, tqdm_class, dry_run)
#    1142     if isinstance(head_call_error, _DEFAULT_RETRY_ON_EXCEPTIONS) or (
#    1143         isinstance(head_call_error, HfHubHTTPError)
#    1144         and head_call_error.response.status_code in _DEFAULT_RETRY_ON_STATUS_CODES
#    1145     ):
#    1146         logger.info("No local file found. Retrying..")
#    1147         (url_to_download, etag, commit_hash, expected_size, xet_file_data, head_call_error) = (
# -> 1148             _get_metadata_or_catch_error(
#    1149                 repo_id=repo_id,
#    1150                 filename=filename,
#    1151                 repo_type=repo_type,
#    1152                 revision=revision,
#    1153                 endpoint=endpoint,
#    1154                 etag_timeout=_ETAG_RETRY_TIMEOUT,
#    1155                 headers=headers,
#    1156                 token=token,
#    1157                 local_files_only=local_files_only,
#    1158                 storage_folder=storage_folder,
#    1159                 relative_filename=relative_filename,
#    1160                 retry_on_errors=True,
#    1161             )
#    1162         )
#    1164 # If still error, raise
#    1165 if head_call_error is not None:
#
# File c:\Users\hugh.dwyer\OneDrive - NSW Department of Education\Desktop\HTML Project\skyrim-semantic-search\venv\Lib\site-packages\huggingface_hub\file_download.py:1690, in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder, retry_on_errors)
#    1688 try:
#    1689     try:
# -> 1690         metadata = get_hf_file_metadata(
#    1691             url=url,
#    1692             timeout=etag_timeout,
#    1693             headers=headers,
#    1694             token=token,
#    1695             endpoint=endpoint,
#    1696             retry_on_errors=retry_on_errors,
#    1697         )
#    1698     except RemoteEntryNotFoundError as http_error:
#    1699         if storage_folder is not None and relative_filename is not None:
#    1700             # Cache the non-existence of the file
#
# File c:\Users\hugh.dwyer\OneDrive - NSW Department of Education\Desktop\HTML Project\skyrim-semantic-search\venv\Lib\site-packages\huggingface_hub\utils\_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File c:\Users\hugh.dwyer\OneDrive - NSW Department of Education\Desktop\HTML Project\skyrim-semantic-search\venv\Lib\site-packages\huggingface_hub\file_download.py:1612, in get_hf_file_metadata(url, token, timeout, library_name, library_version, user_agent, headers, endpoint, retry_on_errors)
#    1609 hf_headers["Accept-Encoding"] = "identity"  # prevent any compression => we want to know the real size of the file
#    1611 # Retrieve metadata
# -> 1612 response = _httpx_follow_relative_redirects_with_backoff(
#    1613     method="HEAD", url=url, headers=hf_headers, timeout=timeout, retry_on_errors=retry_on_errors
#    1614 )
#    1615 hf_raise_for_status(response)
#    1617 # Return
#
# File c:\Users\hugh.dwyer\OneDrive - NSW Department of Education\Desktop\HTML Project\skyrim-semantic-search\venv\Lib\site-packages\huggingface_hub\utils\_http.py:685, in _httpx_follow_relative_redirects_with_backoff(method, url, retry_on_errors, **httpx_kwargs)
#     680 no_retry_kwargs: dict[str, Any] = (
#     681     {} if retry_on_errors else {"retry_on_exceptions": (), "retry_on_status_codes": ()}
#     682 )
#     684 while True:
# --> 685     response = http_backoff(
#     686         method=method,
#     687         url=url,
#     688         **httpx_kwargs,
#     689         follow_redirects=False,
#     690         **no_retry_kwargs,
#     691     )
#     692     hf_raise_for_status(response)
#     694     # Check if response is a relative redirect
#
# File c:\Users\hugh.dwyer\OneDrive - NSW Department of Education\Desktop\HTML Project\skyrim-semantic-search\venv\Lib\site-packages\huggingface_hub\utils\_http.py:559, in http_backoff(method, url, max_retries, base_wait_time, max_wait_time, retry_on_exceptions, retry_on_status_codes, **kwargs)
#     494 def http_backoff(
#     495     method: HTTP_METHOD_T,
#     496     url: str,
#    (...)    503     **kwargs,
#     504 ) -> httpx.Response:
#     505     """Wrapper around httpx to retry calls on an endpoint, with exponential backoff.
#     506
#     507     Endpoint call is retried on exceptions (ex: connection timeout, proxy error,...)
#    (...)    557     > issue on [Github](https://github.com/huggingface/huggingface_hub).
#     558     """
# --> 559     return next(
#     560         _http_backoff_base(
#     561             method=method,
#     562             url=url,
#     563             max_retries=max_retries,
#     564             base_wait_time=base_wait_time,
#     565             max_wait_time=max_wait_time,
#     566             retry_on_exceptions=retry_on_exceptions,
#     567             retry_on_status_codes=retry_on_status_codes,
#     568             stream=False,
#     569             **kwargs,
#     570         )
#     571     )
#
# File c:\Users\hugh.dwyer\OneDrive - NSW Department of Education\Desktop\HTML Project\skyrim-semantic-search\venv\Lib\site-packages\huggingface_hub\utils\_http.py:467, in _http_backoff_base(method, url, max_retries, base_wait_time, max_wait_time, retry_on_exceptions, retry_on_status_codes, stream, **kwargs)
#     465             return
#     466 else:
# --> 467     response = client.request(method=method, url=url, **kwargs)
#     468     if not _should_retry(response):
#     469         yield response
#
# File c:\Users\hugh.dwyer\OneDrive - NSW Department of Education\Desktop\HTML Project\skyrim-semantic-search\venv\Lib\site-packages\httpx\_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File c:\Users\hugh.dwyer\OneDrive - NSW Department of Education\Desktop\HTML Project\skyrim-semantic-search\venv\Lib\site-packages\httpx\_client.py:901, in Client.send(self, request, stream, auth, follow_redirects)
#     887 """
#     888 Send a request.
#     889
#    (...)    898 [0]: /advanced/clients/#request-instances
#     899 """
#     900 if self._state == ClientState.CLOSED:
# --> 901     raise RuntimeError("Cannot send a request, as the client has been closed.")
#     903 self._state = ClientState.OPENED
#     904 follow_redirects = (
#     905     self.follow_redirects
#     906     if isinstance(follow_redirects, UseClientDefault)
#     907     else follow_redirects
#     908 )
#
# RuntimeError: Cannot send a request, as the client has been closed.
